# %% [markdown]
# <h1> Coursera Capstone Notebook </h1>
# <p> This notebook will be used for the <b>Capstone Project</b> for the <b>Data Science</b> professional course by IBM.

# %%
import pandas as pd
import numpy as np

# %%
import requests # library to handle requests
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')

# import k-means from clustering stage
from sklearn.cluster import KMeans
# Out:
# ^C
# ...
# Solving environment: ...working...
# ...
#   - anaconda/win-64::ca-certificates-2020.1.1-0, anaconda/win-64::certifi-2019.11.28-py37_0, anaconda/win-64::openssl-1.1.1d-he774522_4
#   - anaconda/win-64::certifi-2019.11.28-py37_0, anaconda/win-64::openssl-1.1.1d-he774522_4, defaults/win-64::ca-certificates-2020.1.1-0
#   - anaconda/win-64::ca-certificates-2020.1.1-0, anaconda/win-64::openssl-1.1.1d-he774522_4, defaults/win-64::certifi-2019.11.28-py37_0
#   - anaconda/win-64::openssl-1.1.1d-he774522_4, defaults/win-64::ca-certificates-2020.1.1-0, defaults/win-64::certifi-2019.11.28-py37_0
#   - anaconda/win-64::ca-certificates-2020.1.1-0, defaults/win-64::certifi-2019.11.28-py37_0, defaults/win-64::openssl-1.1.1d-he774522_4
#   - defaults/win-64::ca-certificates-2020.1.1-0, defaults/win-64::certifi-2019.11.28-py37_0, defaults/win-64::openssl-1.1.1d-he774522_4
# ...

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# <h3> Week 3 Peer graded assignment </h3>

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

df = pd.read_html(url) #Data Scrapped and in dataframe

df = df[0]
df = df[df['Borough'] != 'Not assigned']
df.reset_index(drop = True,inplace = True)
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# <p> Reading data from csv file to find coordinates </p>

# %%
geospatial_df = pd.read_csv('Geospatial_Coordinates.csv')
geospatial_df
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# <p> Merging coordinates based on postal code</p>

# %%
df = df.merge(geospatial_df,on = 'Postal Code')

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# ...

# %% [markdown]
# Creating a Map

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h5> Extracting Boroughs that have "Toronto" in them </h5>

# %%
toronto_df = df[df['Borough'].str.contains("Toronto")].reset_index(drop=True)
toronto_df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %% [markdown]
# <h2> Function to explore venues </h2>

# %%
CLIENT_ID = 'HQYFRIKBBCCYM2PEQKLONY2UTVQULYS2DKMQ5JQTZSUEIEBW' # your Foursquare ID
CLIENT_SECRET = 'QRPHFK3JWDIMK2W1TM4T5P4G5Y2KU55Q5N3WLLMC53R5X3XV' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version


LIMIT = 100
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&time=any&day=any'.format(
    CLIENT_ID, CLIENT_SECRET, 43.657162, -79.378937, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=HQYFRIKBBCCYM2PEQKLONY2UTVQULYS2DKMQ5JQTZSUEIEBW&client_secret=QRPHFK3JWDIMK2W1TM4T5P4G5Y2KU55Q5N3WLLMC53R5X3XV&ll=43.657162,-79.378937&v=20180605&radius=500&limit=100&time=any&day=any'

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&day=any&time=any'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_df['Neighborhood'],
                                   latitudes=toronto_df['Latitude'],
                                   longitudes=toronto_df['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West, Forest Hill Road Park
# High Park, The Junction South
# North Toronto West, Lawrence Park
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# ...

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (3186, 7)
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 0                  Roselle Desserts       43.653447       -79.362017
# 1                     Tandem Coffee       43.653559       -79.361809
# 2                   Corktown Common       43.655618       -79.356211
# 3  The Distillery Historic District       43.650244       -79.359323
# 4            Cooper Koo Family YMCA       43.653249       -79.358008
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# ...

# %%
toronto_onehot = pd.get_dummies(toronto_venues['Venue Category'],prefix = "", prefix_sep = "")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  Accessories Store  \
# 0                                         Berczy Park               0.00
# 1        Brockton, Parkdale Village, Exhibition Place               0.01
# 2   Business reply mail Processing Centre, South C...               0.00
# 3   CN Tower, King and Spadina, Railway Lands, Har...               0.00
# 4                                  Central Bay Street               0.00
# 5                                            Christie               0.00
# 6                                Church and Wellesley               0.00
# 7                      Commerce Court, Victoria Hotel               0.00
# 8                                          Davisville               0.00
# 9                                    Davisville North               0.00
# 10                       Dufferin, Dovercourt Village               0.00
# 11             First Canadian Place, Underground city               0.00
# ...

# %%
def return_most_common_venues(row,num_of_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending = False)
    return row_categories_sorted.index.values[0:num_of_venues]

# %% [markdown]
# Create a dataframe with the 10 most common venues

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']
# create columns
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{} {} Most Common Venue'.format(ind+1,indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
# creating the dataframe itself
neighborhood_venues_sorted = pd.DataFrame(columns = columns)
neighborhood_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhood_venues_sorted.iloc[ind,1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)
neighborhood_venues_sorted
# Out:
#                                          Neighborhood 1 st Most Common Venue  \
# 0                                         Berczy Park            Coffee Shop
# 1        Brockton, Parkdale Village, Exhibition Place                   Café
# 2   Business reply mail Processing Centre, South C...                   Park
# 3   CN Tower, King and Spadina, Railway Lands, Har...            Coffee Shop
# 4                                  Central Bay Street            Coffee Shop
# 5                                            Christie      Korean Restaurant
# 6                                Church and Wellesley            Coffee Shop
# 7                      Commerce Court, Victoria Hotel            Coffee Shop
# 8                                          Davisville     Italian Restaurant
# 9                                    Davisville North            Coffee Shop
# 10                       Dufferin, Dovercourt Village                   Café
# ...

# %%
kclusters = 10
toronto_grouped =toronto_grouped.drop('Neighborhood', 1)
Kmeans = toronto_grouped_clustering = KMeans(n_clusters = kclusters,random_state = 0).fit(toronto_grouped)
Kmeans.labels_
# Out:
# array([2, 8, 3, 4, 0, 8, 0, 2, 5, 5, 7, 2, 3, 0, 2, 7, 0, 8, 1, 8, 3, 5,
#        7, 0, 5, 2, 6, 9, 5, 2, 0, 2, 7, 3, 8, 0, 5, 2, 8])

# %% [markdown]
# Creating the final table

# %%
neighborhood_venues_sorted.insert(0,'Cluster Label', Kmeans.labels_)

toronto_venues = df
# toronto_venues = toronto_venues.join(neighborhood_venues_sorted.set_index('Neighborhood'), on = 'Neighborhood',how = 'right')

toronto_venues = pd.merge(toronto_venues,neighborhood_venues_sorted, on = 'Neighborhood',how = 'right')

# %% [markdown]
# Plotting

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
map_clusters = folium.Map(location=[43.675, -79.3832], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_venues['Latitude'], toronto_venues['Longitude'], toronto_venues['Neighborhood'], toronto_venues['Cluster Label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] == 0, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#              Borough  Cluster Label 1 st Most Common Venue  \
# 1   Downtown Toronto              0            Coffee Shop
# 2   Downtown Toronto              0            Coffee Shop
# 4       East Toronto              0            Coffee Shop
# 6   Downtown Toronto              0            Coffee Shop
# 15      East Toronto              0      Indian Restaurant
# 35  Downtown Toronto              0                   Café
# 37  Downtown Toronto              0            Coffee Shop
#
#    2 nd Most Common Venue 3 rd Most Common Venue 4th Most Common Venue  \
# 1        Sushi Restaurant    Japanese Restaurant                  Park
# 2     Japanese Restaurant              Gastropub    Italian Restaurant
# 4             Pizza Place                    Pub        Breakfast Spot
# 6        Sushi Restaurant    Japanese Restaurant      Ramen Restaurant
# 15            Coffee Shop                   Café                  Park
# ...

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] == 1, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#             Borough  Cluster Label 1 st Most Common Venue  \
# 18  Central Toronto              1                  Trail
#
#    2 nd Most Common Venue 3 rd Most Common Venue 4th Most Common Venue  \
# 18              Bookstore           College Quad  Gym / Fitness Center
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 18           College Gym           Coffee Shop                  Park
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 18                  Café                   Zoo             Donut Shop

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] == 2, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#              Borough  Cluster Label 1 st Most Common Venue  \
# 3   Downtown Toronto              2            Coffee Shop
# 5   Downtown Toronto              2            Coffee Shop
# 8   Downtown Toronto              2            Coffee Shop
# 10  Downtown Toronto              2            Coffee Shop
# 13  Downtown Toronto              2            Coffee Shop
# 16  Downtown Toronto              2            Coffee Shop
# 34  Downtown Toronto              2            Coffee Shop
# 36  Downtown Toronto              2            Coffee Shop
#
#    2 nd Most Common Venue 3 rd Most Common Venue 4th Most Common Venue  \
# 3                    Café             Restaurant    Italian Restaurant
# 5                   Hotel                   Café   Japanese Restaurant
# 8                    Café                  Hotel               Theater
# 10                  Hotel                   Café                  Park
# 13                   Café                  Hotel   Japanese Restaurant
# ...

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] == 3, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#             Borough  Cluster Label 1 st Most Common Venue  \
# 21  Central Toronto              3                   Park
# 29  Central Toronto              3            Coffee Shop
# 31  Central Toronto              3            Coffee Shop
# 38     East Toronto              3                   Park
#
#    2 nd Most Common Venue 3 rd Most Common Venue 4th Most Common Venue  \
# 21            Coffee Shop                   Café                  Bank
# 29          Grocery Store     Italian Restaurant                   Gym
# 31                   Park       Sushi Restaurant       Thai Restaurant
# 38            Coffee Shop            Pizza Place               Brewery
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 21    Italian Restaurant  Gym / Fitness Center      Sushi Restaurant
# 29                  Park                  Café       Thai Restaurant
# 31    Italian Restaurant         Grocery Store  Gym / Fitness Center
# ...

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] ==4, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#              Borough  Cluster Label 1 st Most Common Venue  \
# 32  Downtown Toronto              4            Coffee Shop
#
#    2 nd Most Common Venue 3 rd Most Common Venue 4th Most Common Venue  \
# 32                   Café        Harbor / Marina          Dance Studio
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 32               Dog Run      Sculpture Garden                 Track
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 32                  Park                Garden         Scenic Lookout

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] == 5, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#              Borough  Cluster Label 1 st Most Common Venue  \
# 0   Downtown Toronto              5            Coffee Shop
# 12      East Toronto              5       Greek Restaurant
# 20   Central Toronto              5            Coffee Shop
# 23   Central Toronto              5            Coffee Shop
# 26   Central Toronto              5     Italian Restaurant
# 28      West Toronto              5            Coffee Shop
#
#    2 nd Most Common Venue 3 rd Most Common Venue 4th Most Common Venue  \
# 0                 Theater                   Café                   Pub
# 12            Coffee Shop                   Café                   Pub
# 20     Italian Restaurant   Fast Food Restaurant                  Café
# 23     Italian Restaurant     Mexican Restaurant                  Café
# 26       Sushi Restaurant            Coffee Shop                  Café
# 28                   Café                 Bakery           Pizza Place
#
# ...

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] == 6, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#              Borough  Cluster Label 1 st Most Common Venue  \
# 33  Downtown Toronto              6            Coffee Shop
#
#    2 nd Most Common Venue 3 rd Most Common Venue 4th Most Common Venue  \
# 33          Grocery Store                   Park              Pie Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 33         Metro Station        Breakfast Spot           Candy Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 33                Bistro        Sandwich Place                 Office

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] == 7, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#          Borough  Cluster Label 1 st Most Common Venue 2 nd Most Common Venue  \
# 9   West Toronto              7                   Café            Coffee Shop
# 17  East Toronto              7            Coffee Shop                    Bar
# 22  West Toronto              7                   Café            Coffee Shop
# 25  West Toronto              7            Pizza Place            Coffee Shop
#
#    3 rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 9                    Park                   Bar       Sushi Restaurant
# 17                   Café                Bakery  Vietnamese Restaurant
# 22                    Bar       Thai Restaurant      Convenience Store
# 25                    Bar        Breakfast Spot       Sushi Restaurant
#
#    6th Most Common Venue        7th Most Common Venue 8th Most Common Venue  \
# 9                 Bakery                 Gourmet Shop    Italian Restaurant
# ...

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] == 8, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#              Borough  Cluster Label 1 st Most Common Venue  \
# 7   Downtown Toronto              8      Korean Restaurant
# 11      West Toronto              8                   Café
# 14      West Toronto              8                   Café
# 24   Central Toronto              8                   Café
# 27  Downtown Toronto              8                   Café
# 30  Downtown Toronto              8                   Café
#
#            2 nd Most Common Venue         3 rd Most Common Venue  \
# 7                            Café                    Coffee Shop
# 11                            Bar  Vegetarian / Vegan Restaurant
# 14                     Restaurant                    Coffee Shop
# 24  Vegetarian / Vegan Restaurant                    Coffee Shop
# 27                         Bakery  Vegetarian / Vegan Restaurant
# 30                            Bar  Vegetarian / Vegan Restaurant
#
#    4th Most Common Venue 5th Most Common Venue   6th Most Common Venue  \
# ...

# %%
toronto_venues.loc[toronto_venues['Cluster Label'] == 9, toronto_venues.columns[[1] + list(range(5, toronto_venues.shape[1]))]]
# Out:
#             Borough  Cluster Label 1 st Most Common Venue  \
# 19  Central Toronto              9            Coffee Shop
#
#    2 nd Most Common Venue 3 rd Most Common Venue 4th Most Common Venue  \
# 19       Sushi Restaurant                   Bank              Pharmacy
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 19                  Café    Italian Restaurant             Gastropub
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 19                Bakery            Bagel Shop    Japanese Restaurant
